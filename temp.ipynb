# %%
import pandas as pd

df = pd.read_csv("bert_embeddings.csv")
print(df.columns[:20])
print("Rows with trend_name = 'AI':", (df["trend_name"] == "AI").sum())
print("Rows with trend_name = '#AI':", (df["trend_name"] == "#AI").sum())

print(df[df["will_trend_tomorrow"] == 1].sample(5)[["trend_name","trend_date","will_trend_tomorrow"]])
# Out:
# Index(['Unnamed: 0', 'trend_date', 'trend_name', 'avg_rank', 'min_rank',
#        'max_rank', 'total_volume', 'appearances', 'is_most_tweeted',
#        'is_longest_trending', 'days_diff', 'will_trend_tomorrow', 'prev_rank',
#        'prev_volume', 'rank_change', 'volume_change', 'day_of_week',
#        'is_weekend', 'month', 'days_since_last_trend'],
#       dtype='object')
# Rows with trend_name = 'AI': 0
# Rows with trend_name = '#AI': 0
#                        trend_name  trend_date  will_trend_tomorrow
# 84767             Gautam Navlakha  2019-10-03                    1
# 7866        #BiharElectionResults  2020-11-09                    1
# 47817              #UPSCaspirants  2024-07-28                    1
# 22785         #IndiaThanksNehruji  2020-05-26                    1
# 140385  गुरुदेव रबीन्द्रनाथ टैगोर  2021-08-06                    1
